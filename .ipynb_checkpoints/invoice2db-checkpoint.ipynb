# %%
from PIL import Image
import os

folder_path = '/home/manasa/Desktop/Code/hackathon/pdf_images'

# List all PNG files in the folder
image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.png')]

print(image_paths)

images = [Image.open(path) for path in image_paths]
# Out:
# ['/home/manasa/Desktop/Code/hackathon/pdf_images/254_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/299_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/429_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/676_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_2.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/450_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/232_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/261_page_1.png', '/home/manasa/Desktop/Code/hackathon/pdf_images/421_page_1.png']

# %%
import google.generativeai as genai
import os


os.environ['GOOGLE_API_KEY'] = 'AIzaSyDM2ks9JroT_5fG2WD4tfkHX6bzejhTKqo'
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

model = genai.GenerativeModel('gemini-1.5-flash')
# Folder where images are stored
image = Image.open("/home/manasa/Desktop/Code/hackathon/pdf_images/1059_page_1.png")
prompt = """Analyze these grocery bill invoices. For each edible product listed, provide a comprehensive nutritional and environmental assessment based on the estimated quantity purchased. Use the following format for each product:

    {
        "product_name": "",
        "price_paid": 0,
        "num_items": 0,
        "estimated_quantity": {"value": 0, "unit": ""},
        "serving_size": "",
        "energy": {
            "per_serving": {"value": 0, "unit": "kcal"}
        },
        "macronutrients": {
            "total_fat": {"per_serving": {"value": 0, "unit": "g"}},
            "carbohydrates": {"per_serving": {"value": 0, "unit": "g"}},
            "protein": {"per_serving": {"value": 0, "unit": "g"}}
        },
        "micronutrients": {
            "sodium": {"per_serving": {"value": 0, "unit": "mg"}},
            "key_vitamins_minerals": [
                {"name": "", "value": 0, "unit": ""}
            ]
        },
        "fiber": {
            "total": {"per_serving": {"value": 0, "unit": "g"}},
            "soluble": {"per_serving": {"value": 0, "unit": "g"}},
            "insoluble": {"per_serving": {"value": 0, "unit": "g"}}
        },
        "allergens": [],
        "nutrient_density_score": {
            "value": 0,
            "category": ""
        },
        "glycemic_index": {
            "value": 0,
            "category": ""
        },
        "glycemic_load": 0,
        "protein_quality": {
            "score": 0,
            "method": "PDCAAS/DIAAS"
        },
        "phytonutrients": [
            {"name": "", "presence": "high/medium/low"}
        ],
        "micronutrient_density": {
            "per_100_calories": [
                {"nutrient": "", "value": 0, "unit": ""}
            ],
            "per_100_grams": [
                {"nutrient": "", "value": 0, "unit": ""}
            ]
        },
        "satiety_index": {
            "value": 0,
            "category": ""
        },
        "environmental_impact": {
            "water_usage": {"value": 0, "unit": "L/kg"},
            "carbon_footprint": {
                "value": 0,
                "unit": "kg CO2e/kg",
                "category": ""
            },
            "land_use": {"value": 0, "unit": "m²/kg"}
        },
        "versatility_score": {
            "value": 0,
            "category": ""
        },
        "cost_nutrient_ratio": {
            "value": 0,
            "category": ""
        },
        "nutritional_summary": ""
    }

    Estimate the quantity based on the price paid and typical market prices. Provide rough estimates for nutritional content and environmental impact based on this estimated quantity. If certain information is not applicable or available, you may omit those fields. Focus on providing a general nutritional and environmental overview rather than precise values.

    For each metric:
    1. Nutrient Density Score: Calculate based on vitamin, mineral, fiber, and protein content relative to calorie content. Categorize into four thresholds: "Very Low" (0-25), "Low" (26-50), "Medium" (51-75), "High" (76-100).
    2. Glycemic Index: Assess these values, noting that foods like lentils and pulses typically have low values. Categorize as "Low" (0-55), "Medium" (56-69), "High" (70-100), "Very High" (>100).
    3. Satiety Index: Provide an estimate of how filling the food is relative to its calorie content. Categorize as "Low" (0-25), "Medium" (26-50), "High" (51-75), "Very High" (76-100).
    4. Carbon Footprint: Include metrics on carbon footprint for production. Categorize as "Low" (0-1 kg CO2e/kg), "Medium" (1-5 kg CO2e/kg), "High" (5-10 kg CO2e/kg), "Very High" (>10 kg CO2e/kg).
    5. Versatility Score: Develop a score based on the food's adaptability to various dishes and cuisines. Categorize as "Low" (0-25), "Medium" (26-50), "High" (51-75), "Very High" (76-100).
    6. Cost-Nutrient Ratio: Calculate the nutritional value provided per unit of cost. Categorize as "Poor" (0-25), "Fair" (26-50), "Good" (51-75), "Excellent" (76-100).

    List all edible products from the invoices in this format, highlighting the nutritional benefits of foods like lentils, pulses, and other nutrient-dense options.

    Additionally, provide a summary of the nutrient density distribution across all products in a format suitable for creating a pie chart with the four categories: Very Low, Low, Medium, and High.

    Finally, create a table summarizing the following metrics for each product:
    | Product | Cost-Nutrient Ratio | Satiety Index | Glycemic Index | Carbon Footprint | Versatility Score |
    
"""

# Generate content with multiple images
response = model.generate_content([prompt, image])

print(response.text)
# Out:
# ```json
# [
#     {
#         "product_name": "Too Yumm - Naagin Sauce - Smoking Hot Bhoot Chips",
#         "price_paid": 19.00,
#         "num_items": 1,
#         "estimated_quantity": {
#             "value": 1,
#             "unit": "packet"
#         },
#         "serving_size": "1 serving",
#         "energy": {
#             "per_serving": {
#                 "value": 150,
#                 "unit": "kcal"
#             }
#         },
#         "macronutrients": {
#             "total_fat": {
#                 "per_serving": {
#                     "value": 10,
#                     "unit": "g"
#                 }
#             },
#             "carbohydrates": {
#                 "per_serving": {
#                     "value": 15,
#                     "unit": "g"
#                 }
#             },
#             "protein": {
#                 "per_serving": {
#                     "value": 2,
#                     "unit": "g"
#                 }
#             }
# ...

# %% [markdown]
# gemini pro

# %%
print(response)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
# ...

# %%
import os
import pickle
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import Flow
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import Flow

def get_gmail_service():
    creds = None
    credentials_path = '/home/manasa/Desktop/Code/hackathon/gmail_credentials.json'
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = Flow.from_client_secrets_file(
                credentials_path,
                scopes=['https://www.googleapis.com/auth/gmail.readonly'],
                redirect_uri='http://localhost:8080'
            )
            auth_url, _ = flow.authorization_url(prompt='consent')
            print(f'Please go to this URL: {auth_url}')
            code = input('Enter the authorization code: ')
            flow.fetch_token(code=code)
            creds = flow.credentials
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return build('gmail', 'v1', credentials=creds)

def search_messages(service, query):
    result = service.users().messages().list(userId='me', q=query).execute()
    messages = []
    if 'messages' in result:
        messages.extend(result['messages'])
    while 'nextPageToken' in result:
        page_token = result['nextPageToken']
        result = service.users().messages().list(userId='me', q=query, pageToken=page_token).execute()
        if 'messages' in result:
            messages.extend(result['messages'])
    return messages

def get_message_content(service, message_id):
    msg = service.users().messages().get(userId='me', id=message_id, format='full').execute()
    payload = msg['payload']
    headers = payload['headers']
    subject = next(header['value'] for header in headers if header['name'].lower() == 'subject')
    sender = next(header['value'] for header in headers if header['name'].lower() == 'from')
    
    if 'parts' in payload:
        parts = payload['parts']
        data = parts[0]['body']['data']
    else:
        data = payload['body']['data']
    
    data = data.replace("-","+").replace("_","/")
    decoded_data = base64.b64decode(data)
    return subject, sender, decoded_data.decode()

def main():
    service = get_gmail_service()
    query = "subject:(invoice OR receipt) (grocery OR supermarket)"
    messages = search_messages(service, query)
    
    for message in messages:
        subject, sender, content = get_message_content(service, message['id'])
        print(f"Subject: {subject}")
        print(f"From: {sender}")
        print(f"Content: {content[:200]}...")  # Print first 200 characters
        print("--------------------")

if __name__ == '__main__':
    main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=697489352292-f8053d1lrnrsppsobt5mp81jr856vfip.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly&state=BJGiOoMDNADSwDnS7wMQ73vHgZMgiG&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 76
#      73         print("--------------------")
#      75 if __name__ == '__main__':
# ---> 76     main()
#
# Cell In[9], line 64, in main()
#      63 def main():
# ---> 64     service = get_gmail_service()
#      65     query = "subject:(invoice OR receipt) (grocery OR supermarket)"
#      66     messages = search_messages(service, query)
#
# Cell In[9], line 29, in get_gmail_service()
#      23 else:
# ...

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

# For testing purposes, directly assign the string
gemini_output = "test"

# Format data for Firebase
firebase_data = {
    "invoices": gemini_output
}

# Initialize Firebase app
cred = credentials.Certificate("/home/manasa/Desktop/Code/hackathon/consciouscart-16d52-firebase-adminsdk-760qa-40f97a51ac.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://consciouscart-16d52-default-rtdb.firebaseio.com/'
})

# Get a reference to the database
ref = db.reference('/')

# Upload the data to Firebase
ref.set(firebase_data)

print("Data successfully uploaded to Firebase!")
# Out:
# Data successfully uploaded to Firebase!

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db

# Assuming 'response' is the Gemini API response object
gemini_output = response.text  # or response.content, depending on the exact structure

# Format data for Firebase
firebase_data = {
    "products": gemini_output
}

# Initialize Firebase app
cred = credentials.Certificate("/home/manasa/Desktop/Code/hackathon/consciouscart-16d52-firebase-adminsdk-760qa-40f97a51ac.json")
firebase_admin.initialize_app(cred, {
    'databaseURL': 'https://consciouscart-16d52-default-rtdb.firebaseio.com/'
})

# Get a reference to the database
ref = db.reference('/')

# Upload the data to Firebase
ref.set(firebase_data)

print("Data successfully uploaded to Firebase!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 6
#       3 from firebase_admin import db
#       5 # Assuming 'response' is the Gemini API response object
# ----> 6 gemini_output = response.text  # or response.content, depending on the exact structure
#       8 # Format data for Firebase
#       9 firebase_data = {
#      10     "inoivces": gemini_output
#      11 }
#
# AttributeError: 'str' object has no attribute 'text'

# %%
import os.path
import json
import base64
import os
import re
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build

# If modifying these SCOPES, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/gmail.readonly']

def authenticate_gmail():
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is created automatically
    # when the authorization flow completes for the first time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                '/home/manasa/Desktop/Code/hackathon/gmail_credentials.json', SCOPES)
            creds = flow.run_local_server(port=8080)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())
    return creds

def get_emails(service):
    # Call the Gmail API
    results = service.users().messages().list(userId='me', maxResults=5).execute()
    messages = results.get('messages', [])
    
    if not messages:
        print('No new messages.')
    else:
        for message in messages:
            msg = service.users().messages().get(userId='me', id=message['id']).execute()
            msg_snippet = msg['snippet']
            msg_payload = msg['payload']
            msg_headers = msg_payload.get('headers', [])
            subject = next(header['value'] for header in msg_headers if header['name'] == 'Subject')
            from_email = next(header['value'] for header in msg_headers if header['name'] == 'From')
            print(f"From: {from_email}\nSubject: {subject}\nSnippet: {msg_snippet}\n")

def main():
    creds = authenticate_gmail()
    service = build('gmail', 'v1', credentials=creds)
    get_emails(service)

if __name__ == '__main__':
    main()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=697489352292-f8053d1lrnrsppsobt5mp81jr856vfip.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A44937%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.readonly&state=TAmtPl9EmmobZU73eRqqVYeWFEwcIZ&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 56
#      53     get_emails(service)
#      55 if __name__ == '__main__':
# ---> 56     main()
#
# Cell In[14], line 51, in main()
#      50 def main():
# ---> 51     creds = authenticate_gmail()
#      52     service = build('gmail', 'v1', credentials=creds)
#      53     get_emails(service)
#
# Cell In[14], line 27, in authenticate_gmail()
#      24 else:
#      25     flow = InstalledAppFlow.from_client_secrets_file(
# ...
